# %%
import json
import data_utils
import conceptset_utils

# %%
"""
CLASS_SIM_CUTOFF: Concenpts with cos similarity higher than this to any class will be removed
OTHER_SIM_CUTOFF: Concenpts with cos similarity higher than this to another concept will be removed
MAX_LEN: max number of characters in a concept

PRINT_PROB: what percentage of filtered concepts will be printed
"""

CLASS_SIM_CUTOFF = 0.85
OTHER_SIM_CUTOFF = 0.9
MAX_LEN = 30
PRINT_PROB = 1
SEED=3456

dataset = "cifar100_task_4_3456"
dataset_old = "cifar100_task4_3456"
device = "cuda"

save_name = "data/concept_sets/{}_c2_filtered.txt".format(dataset)

# %%
classes=[]
init_concepts=set()

# %%
#EDIT these to use the initial concept sets you want

with open("data/concept_sets/gpt3_init/SEED_{}/gpt3_{}_important.json".format(SEED,dataset_old), "r") as f:
    important_dict = json.load(f)
with open("data/concept_sets/gpt3_init/SEED_{}/gpt3_{}_superclass.json".format(SEED,dataset_old), "r") as f:
    superclass_dict = json.load(f)
with open("data/concept_sets/gpt3_init/SEED_{}/gpt3_{}_around.json".format(SEED,dataset_old), "r") as f:
    around_dict = json.load(f)

#classes=[] c1

with open(data_utils.LABEL_FILES[dataset], "r") as f:
    classes_new = f.read().split("\n")
classes+=classes_new

# %%
print(classes)
print(len(classes))
# Out:
# ['bear', 'bee', 'butterfly', 'camel', 'caterpillar', 'chair', 'elephant', 'forest', 'hamster', 'lion', 'motorcycle', 'otter', 'plate', 'sea', 'shark', 'shrew', 'spider', 'tank', 'train', 'willow tree', 'beaver', 'bowl', 'boy', 'bridge', 'castle', 'cockroach', 'couch', 'dinosaur', 'house', 'keyboard', 'lawn mower', 'mushroom', 'pear', 'pickup truck', 'poppy', 'possum', 'ray', 'skyscraper', 'wardrobe', 'whale', 'beetle', 'cloud', 'crocodile', 'lamp', 'leopard', 'lizard', 'palm tree', 'pine tree', 'porcupine', 'snail', 'streetcar', 'sweet pepper', 'table', 'telephone', 'television', 'tiger', 'tulip', 'turtle', 'woman', 'worm', 'baby', 'bed', 'bicycle', 'bottle', 'can', 'chimpanzee', 'crab', 'lobster', 'man', 'maple tree', 'mouse', 'oak tree', 'orchid', 'plain', 'road', 'rocket', 'rose', 'skunk', 'squirrel', 'trout', 'apple', 'aquarium fish', 'bus', 'cattle', 'clock', 'cup', 'dolphin', 'flatfish', 'fox', 'girl', 'kangaroo', 'mountain', 'orange', 'rabbit', 'raccoon', 'seal', 'snake', 'sunflower', 'tractor', 'wolf']
# 100

# %%
#concepts = set() c1

for values in important_dict.values():
    init_concepts.update(set(values))

for values in superclass_dict.values():
    init_concepts.update(set(values))
    
for values in around_dict.values():
    init_concepts.update(set(values))

print(len(concepts))
# Out:
# 747

# %%
concepts=init_concepts

# %%
concepts = conceptset_utils.remove_too_long(concepts, MAX_LEN, PRINT_PROB)
# Out:
# 1188 1188

# %%
concepts = conceptset_utils.filter_too_similar_to_cls(concepts, classes, CLASS_SIM_CUTOFF, device, PRINT_PROB)
# Out:
# 1188
# Class:bee - Deleting a bee
# Class:butterfly - Deleting a butterfly
# Class:caterpillar - Deleting a caterpillar
# Class:chair - Deleting a chair
# Class:forest - Deleting a forest
# Class:forest - Deleting the forest
# Class:motorcycle - Deleting a motorcycle
# Class:plate - Deleting a plate
# Class:sea - Deleting a sea
# Class:sea - Deleting the sea
# Class:tank - Deleting a tank
# Class:bowl - Deleting a bowl
# Class:boy - Deleting a boy
# Class:couch - Deleting a couch
# Class:house - Deleting a house
# Class:keyboard - Deleting a keyboard
# Class:mushroom - Deleting a mushroom
# Class:whale - Deleting a whale
# Class:beetle - Deleting a beetle
# Class:lamp - Deleting a lamp
# Class:lizard - Deleting a lizard
# Class:palm tree - Deleting a palm tree
# Class:porcupine - Deleting a porcupine
# Class:streetcar - Deleting a streetcar
# Class:table - Deleting a table
# Class:television - Deleting a television
# Class:woman - Deleting a woman
# Class:worm - Deleting a worm
# Class:baby - Deleting a baby
# Class:bed - Deleting a bed
# Class:bicycle - Deleting a bicycle
# Class:bottle - Deleting a bottle
# Class:chimpanzee - Deleting a chimpanzee
# Class:lobster - Deleting a lobster
# Class:man - Deleting a man
# Class:mouse - Deleting a mouse
# Class:road - Deleting a road
# Class:skunk - Deleting a skunk
# Class:squirrel - Deleting a squirrel
# Class:apple - Deleting an apple
# Class:bus - Deleting a bus
# Class:cup - Deleting cup
# Class:cup - Deleting a cup
# Class:dolphin - Deleting a dolphin
# Class:snake - Deleting a snake
# Class:tractor - Deleting a tractor
# 1142
# Class:chair - Concept:a seat, sim:0.870 - Deleting a seat
#
# Class:lion - Concept:a lioness, sim:0.870 - Deleting a lioness
#
# Class:motorcycle - Concept:a bike, sim:0.883 - Deleting a bike
#
# Class:sea - Concept:a ocean, sim:0.865 - Deleting a ocean
#
# Class:sea - Concept:an ocean, sim:0.859 - Deleting an ocean
#
# Class:sea - Concept:ocean, sim:0.925 - Deleting ocean
#
# Class:sea - Concept:the ocean, sim:0.856 - Deleting the ocean
#
# Class:spider - Concept:arachnid, sim:0.885 - Deleting arachnid
#
# Class:couch - Concept:a sofa, sim:0.856 - Deleting a sofa
#
# Class:house - Concept:a home, sim:0.854 - Deleting a home
#
# Class:pickup truck - Concept:a truck, sim:0.916 - Deleting a truck
#
# Class:pickup truck - Concept:truck, sim:0.933 - Deleting truck
#
# Class:pickup truck - Concept:trucks, sim:0.884 - Deleting trucks
#
# Class:pickup truck - Concept:vehicle, sim:0.859 - Deleting vehicle
#
# Class:possum - Concept:a mother possum, sim:0.885 - Deleting a mother possum
#
# Class:wardrobe - Concept:clothes, sim:0.897 - Deleting clothes
#
# Class:whale - Concept:other whales, sim:0.908 - Deleting other whales
#
# Class:lizard - Concept:reptile, sim:0.880 - Deleting reptile
#
# Class:pine tree - Concept:a tree, sim:0.853 - Deleting a tree
#
# Class:pine tree - Concept:pine needles, sim:0.863 - Deleting pine needles
#
# Class:pine tree - Concept:tree, sim:0.861 - Deleting tree
#
# Class:snail - Concept:gastropod, sim:0.856 - Deleting gastropod
#
# Class:sweet pepper - Concept:pepper, sim:0.876 - Deleting pepper
#
# Class:television - Concept:a TV, sim:0.864 - Deleting a TV
#
# Class:bicycle - Concept:a bicyclist, sim:0.865 - Deleting a bicyclist
#
# Class:bottle - Concept:a water bottle, sim:0.864 - Deleting a water bottle
#
# Class:chimpanzee - Concept:primate, sim:0.865 - Deleting primate
#
# Class:crab - Concept:crustacean, sim:0.850 - Deleting crustacean
#
# Class:lobster - Concept:a large, lobster-like creature, sim:0.862 - Deleting a large, lobster-like creature
#
# Class:lobster - Concept:a lobster cracker, sim:0.858 - Deleting a lobster cracker
#
# Class:road - Concept:a highway, sim:0.877 - Deleting a highway
#
# Class:road - Concept:street, sim:0.884 - Deleting street
#
# Class:road - Concept:streets, sim:0.862 - Deleting streets
#
# Class:rocket - Concept:a rocket ship, sim:0.873 - Deleting a rocket ship
#
# Class:squirrel - Concept:squirrels, sim:0.921 - Deleting squirrels
#
# Class:aquarium fish - Concept:a fish, sim:0.852 - Deleting a fish
#
# Class:aquarium fish - Concept:an aquarium, sim:0.874 - Deleting an aquarium
#
# Class:aquarium fish - Concept:aquarium, sim:0.898 - Deleting aquarium
#
# Class:aquarium fish - Concept:fish, sim:0.869 - Deleting fish
#
# Class:bus - Concept:a bus route, sim:0.877 - Deleting a bus route
#
# Class:cattle - Concept:a cow, sim:0.855 - Deleting a cow
#
# Class:cattle - Concept:cows, sim:0.910 - Deleting cows
#
# Class:cattle - Concept:livestock, sim:0.898 - Deleting livestock
#
# Class:clock - Concept:a clock face, sim:0.881 - Deleting a clock face
#
# Class:cup - Concept:a coffee cup, sim:0.858 - Deleting a coffee cup
#
# Class:orange - Concept:a bright orange color, sim:0.871 - Deleting a bright orange color
#
# Class:raccoon - Concept:a female raccoon, sim:0.904 - Deleting a female raccoon
#
# 1095

# %%
concepts = conceptset_utils.filter_too_similar(concepts, OTHER_SIM_CUTOFF, device, PRINT_PROB)
# Out:
# 2 small wings - a pair of wings , sim:0.9226 - Deleting 2 small wings
# 6 legs - eight legs , sim:0.9412 - Deleting 6 legs
# Food - food , sim:0.9995 - Deleting food
# a animal - a dog , sim:0.9301 - Deleting a dog
# a animal - a mammal , sim:0.9173 - Deleting a mammal
# a animal - animal , sim:0.9200 - Deleting animal
# a base - a large base , sim:0.9221 - Deleting a large base
# a bedside table - a nightstand , sim:0.9176 - Deleting a bedside table
# a big head - a big head with a wide mouth , sim:0.9327 - Deleting a big head with a wide mouth
# a big head - a large head , sim:0.9659 - Deleting a large head
# a black center - a black or dark center , sim:0.9355 - Deleting a black or dark center
# a black center - a brown or black center , sim:0.9021 - Deleting a brown or black center
# a blanket - a comforter or blanket , sim:0.9033 - Deleting a comforter or blanket
# a blossom - a flower , sim:0.9007 - Deleting a blossom
# a body of water - a large body of water , sim:0.9589 - Deleting a large body of water
# a body of water - body of water , sim:0.9738 - Deleting body of water
# a branch - branches , sim:0.9068 - Deleting branches
# a bright color - a light color , sim:0.9164 - Deleting a bright color
# a bright red or orange color - a bright, red color , sim:0.9301 - Deleting a bright red or orange color
# a bulb - a bulb at the base , sim:0.9100 - Deleting a bulb at the base
# a bulb - a light bulb , sim:0.9634 - Deleting a bulb
# a bus pass - a bus ticket , sim:0.9185 - Deleting a bus ticket
# a bushy tail - a fluffy tail , sim:0.9066 - Deleting a fluffy tail
# a bushy tail - a long, bushy tail , sim:0.9682 - Deleting a long, bushy tail
# a bushy tail - a tail , sim:0.9013 - Deleting a bushy tail
# a cab for passengers - a cab for the driver , sim:0.9533 - Deleting a cab for passengers
# a car - a vehicle , sim:0.9390 - Deleting a car
# a child - child , sim:0.9277 - Deleting child
# a cord - a phone cord , sim:0.9196 - Deleting a phone cord
# a cord - a power cord , sim:0.9048 - Deleting a power cord
# a crown of leaves - a crown of leaves at the top , sim:0.9523 - Deleting a crown of leaves
# a cylindrical shape - a long, cylindrical shape , sim:0.9617 - Deleting a cylindrical shape
# a dark brown or black color - a gray or light brown color , sim:0.9081 - Deleting a gray or light brown color
# a dark brown or black color - a light or dark color , sim:0.9030 - Deleting a dark brown or black color
# a deep voice - a soft voice , sim:0.9140 - Deleting a soft voice
# a desert - a desert environment , sim:0.9242 - Deleting a desert environment
# a father - a parent , sim:0.9219 - Deleting a father
# a feminine face - a masculine face , sim:0.9159 - Deleting a masculine face
# a field - fields , sim:0.9136 - Deleting fields
# a flat surface - a large, flat surface , sim:0.9530 - Deleting a flat surface
# a flat, circular shape - a flat, rectangular shape , sim:0.9166 - Deleting a flat, circular shape
# a flat, rectangular shape - a large, rectangular shape , sim:0.9314 - Deleting a flat, rectangular shape
# a flower - flower , sim:0.9342 - Deleting flower
# a foul smell - a smell , sim:0.9108 - Deleting a foul smell
# a frame - a sturdy frame , sim:0.9029 - Deleting a sturdy frame
# a fridge - a refrigerator , sim:0.9618 - Deleting a refrigerator
# a furry coat - furry coat , sim:0.9708 - Deleting furry coat
# a glass - glass , sim:0.9066 - Deleting glass
# a green stem - a stem with green leaves , sim:0.9114 - Deleting a stem with green leaves
# a handlebar - handlebars , sim:0.9281 - Deleting handlebars
# a handset - a phone , sim:0.9182 - Deleting a handset
# a hard exoskeleton - a hard, exoskeleton shell , sim:0.9099 - Deleting a hard, exoskeleton shell
# a hard shell - a hard, outer shell , sim:0.9215 - Deleting a hard shell
# a hard, outer shell - a small, hard shell , sim:0.9122 - Deleting a small, hard shell
# a head - a small head , sim:0.9032 - Deleting a head
# a hump - a humped back , sim:0.9080 - Deleting a humped back
# a insect - insect , sim:0.9587 - Deleting insect
# a jungle - jungle , sim:0.9479 - Deleting jungle
# a label - a label or design , sim:0.9285 - Deleting a label or design
# a large body - a large, boxy body , sim:0.9017 - Deleting a large, boxy body
# a large body - a large, bulky body , sim:0.9220 - Deleting a large, bulky body
# a large body - a large, flat body , sim:0.9051 - Deleting a large, flat body
# a large body - a large, muscular body , sim:0.9227 - Deleting a large body
# a large mouth with sharp teeth - large, sharp teeth , sim:0.9240 - Deleting a large mouth with sharp teeth
# a large size - large size , sim:0.9527 - Deleting large size
# a large, boxy shape - a large, rectangular shape , sim:0.9155 - Deleting a large, rectangular shape
# a large, colorful bloom - a large, colorful flower , sim:0.9232 - Deleting a large, colorful bloom
# a large, colorful flower - a large, showy flower , sim:0.9087 - Deleting a large, colorful flower
# a large, elongated body - a long, rectangular body , sim:0.9001 - Deleting a long, rectangular body
# a large, flat surface - a long, flat surface , sim:0.9491 - Deleting a long, flat surface
# a large, metal engine - a large, powerful engine , sim:0.9022 - Deleting a large, metal engine
# a large, metal vehicle - a vehicle , sim:0.9118 - Deleting a large, metal vehicle
# a large, muscular body - a large, stocky body , sim:0.9200 - Deleting a large, stocky body
# a large, muscular body - a lithe, muscular body , sim:0.9208 - Deleting a lithe, muscular body
# a large, muscular body - a muscular body , sim:0.9532 - Deleting a muscular body
# a large, rodent-like body - a small, rodent-like body , sim:0.9497 - Deleting a large, rodent-like body
# a large, round head - a small, round head , sim:0.9455 - Deleting a large, round head
# a lid - usually has a lid , sim:0.9002 - Deleting usually has a lid
# a light - a light bulb , sim:0.9082 - Deleting a light bulb
# a light - a lightbulb , sim:0.9011 - Deleting a lightbulb
# a light - light , sim:0.9136 - Deleting light
# a light color - a light or dark color , sim:0.9507 - Deleting a light or dark color
# a locomotive - a locomotive at the front , sim:0.9056 - Deleting a locomotive at the front
# a long body - a long, narrow body , sim:0.9035 - Deleting a long body
# a long mane around the head - a mane of thick, long hair , sim:0.9131 - Deleting a mane of thick, long hair
# a long neck - a long, curved neck , sim:0.9106 - Deleting a long neck
# a long snout - a long, pointed snout , sim:0.9226 - Deleting a long snout
# a long stem - a long, thick stem , sim:0.9619 - Deleting a long, thick stem
# a long stem - a long, thin stem , sim:0.9623 - Deleting a long, thin stem
# a long stem - a slender stem , sim:0.9277 - Deleting a slender stem
# a long stem - a stem , sim:0.9059 - Deleting a long stem
# a long tail - a long, flowing tail , sim:0.9089 - Deleting a long tail
# a long trunk - a long, slender trunk , sim:0.9132 - Deleting a long trunk
# a long, beak-like nose - a long, curved nose , sim:0.9127 - Deleting a long, beak-like nose
# a long, coiled tail - a long, flowing tail , sim:0.9148 - Deleting a long, coiled tail
# a long, curved neck - a long, thin neck , sim:0.9377 - Deleting a long, curved neck
# a long, flowing tail - a long, powerful tail , sim:0.9377 - Deleting a long, flowing tail
# a long, naked tail - a long, skinny tail , sim:0.9114 - Deleting a long, naked tail
# a long, narrow body - a long, narrow shape , sim:0.9198 - Deleting a long, narrow body
# a long, narrow shape - a long, thin shape , sim:0.9547 - Deleting a long, narrow shape
# a long, pointed snout - a pointed snout , sim:0.9628 - Deleting a long, pointed snout
# a long, powerful tail - a long, prehensile tail , sim:0.9106 - Deleting a long, prehensile tail
# a long, powerful tail - a long, skinny tail , sim:0.9049 - Deleting a long, powerful tail
# a long, segmented tail - a long, sinuous tail , sim:0.9025 - Deleting a long, segmented tail
# a long, skinny tail - a long, thick tail , sim:0.9356 - Deleting a long, skinny tail
# a long, slender body - a long, slim body , sim:0.9579 - Deleting a long, slim body
# a long, slender body - a long, thin body , sim:0.9490 - Deleting a long, slender body
# a long, slender trunk - a slender trunk , sim:0.9689 - Deleting a slender trunk
# a long, slender trunk - a tall, slender trunk , sim:0.9707 - Deleting a tall, slender trunk
# a long, slender trunk - tall with a slender trunk , sim:0.9040 - Deleting tall with a slender trunk
# a long, thick tail - a short tail , sim:0.9005 - Deleting a short tail
# a long, thick tail - a tail , sim:0.9078 - Deleting a tail
# a long, thick tail - a wide, flat tail , sim:0.9029 - Deleting a wide, flat tail
# a long, thick tail - large, flat tail , sim:0.9056 - Deleting large, flat tail
# a long, thin antennae - long antennae , sim:0.9287 - Deleting long antennae
# a long, thin body - a long, thin shape , sim:0.9013 - Deleting a long, thin body
# a long, thin shape - a slender, tapered shape , sim:0.9051 - Deleting a slender, tapered shape
# a metal or plastic body - a metal or plastic exterior , sim:0.9118 - Deleting a metal or plastic exterior
# a minute hand - an hour hand , sim:0.9193 - Deleting a minute hand
# a moat - surrounded by a moat , sim:0.9196 - Deleting surrounded by a moat
# a mother - a parent , sim:0.9054 - Deleting a mother
# a mouse pad - a mousepad , sim:0.9631 - Deleting a mousepad
# a pair of antennae - two antennae , sim:0.9485 - Deleting two antennae
# a pair of jeans - a pair of pants , sim:0.9200 - Deleting a pair of jeans
# a pair of pants - a pants , sim:0.9351 - Deleting a pair of pants
# a pair of wings - two large, wings , sim:0.9171 - Deleting two large, wings
# a pair of wings - two pairs of wings , sim:0.9509 - Deleting two pairs of wings
# a pair of wings - two wings , sim:0.9333 - Deleting two wings
# a path - path , sim:0.9296 - Deleting path
# a plant - plant , sim:0.9177 - Deleting plant
# a pointed end - pointed at one end , sim:0.9005 - Deleting pointed at one end
# a pointed head - a small, pointed head , sim:0.9559 - Deleting a pointed head
# a pointed nose - a small, pointed nose , sim:0.9679 - Deleting a pointed nose
# a pointed or peaked top - a pointed top , sim:0.9089 - Deleting a pointed or peaked top
# a pointed snout - a snout , sim:0.9091 - Deleting a pointed snout
# a pointed top - a small, pointed top , sim:0.9526 - Deleting a pointed top
# a power outlet - an electrical outlet , sim:0.9444 - Deleting a power outlet
# a prey - a prey animal , sim:0.9397 - Deleting a prey animal
# a prey - prey , sim:0.9249 - Deleting prey
# a rectangular shape - a round or rectangular shape , sim:0.9292 - Deleting a round or rectangular shape
# a rectangular shape - a small, rectangular shape , sim:0.9619 - Deleting a rectangular shape
# a red or dark brown color - red or brown color , sim:0.9449 - Deleting red or brown color
# a red, green, or yellow color - red, green, or yellow color , sim:0.9739 - Deleting red, green, or yellow color
# a rim around the edge - a rim around the top , sim:0.9343 - Deleting a rim around the edge
# a round body - a round or oval body , sim:0.9490 - Deleting a round or oval body
# a round body - a round shape , sim:0.9099 - Deleting a round body
# a round or oval shape - a round shape , sim:0.9576 - Deleting a round or oval shape
# a round shape - a small, round or oval shape , sim:0.9413 - Deleting a small, round or oval shape
# a round shape - a small, round shape , sim:0.9569 - Deleting a round shape
# a rounded body - a small, round body , sim:0.9035 - Deleting a rounded body
# a seat for a person - a seat for the rider , sim:0.9024 - Deleting a seat for a person
# a shirt - a t-shirt , sim:0.9560 - Deleting a t-shirt
# a short muzzle - a small, pointed muzzle , sim:0.9354 - Deleting a small, pointed muzzle
# a short muzzle - muzzle , sim:0.9184 - Deleting muzzle
# a sleek, streamlined body - a streamlined body , sim:0.9368 - Deleting a sleek, streamlined body
# a small body - a small, dark body , sim:0.9163 - Deleting a small, dark body
# a small body - a small, flat body , sim:0.9074 - Deleting a small, flat body
# a small body - a small, round body , sim:0.9302 - Deleting a small body
# a small head - a small, pointed head , sim:0.9269 - Deleting a small, pointed head
# a small head - a small, round head , sim:0.9468 - Deleting a small, round head
# a small, furry body - furry body , sim:0.9155 - Deleting furry body
# a small, mouse-like body - a small, rodent-like body , sim:0.9431 - Deleting a small, mouse-like body
# a small, pointed nose - pointed nose , sim:0.9286 - Deleting pointed nose
# a small, rectangular shape - a small, round shape , sim:0.9172 - Deleting a small, rectangular shape
# a small, round body - a small, round shape , sim:0.9213 - Deleting a small, round body
# a small, round shape - round shape , sim:0.9426 - Deleting round shape
# a small, slimy body - a soft, slimy body , sim:0.9474 - Deleting a soft, slimy body
# a smell - a strong scent , sim:0.9109 - Deleting a strong scent
# a smell - a strong smell , sim:0.9466 - Deleting a strong smell
# a smooth or bumpy surface - a smooth surface , sim:0.9241 - Deleting a smooth or bumpy surface
# a sturdy build - a sturdy construction , sim:0.9280 - Deleting a sturdy build
# a sturdy construction - a sturdy material , sim:0.9025 - Deleting a sturdy construction
# a toy - a toys , sim:0.9506 - Deleting a toys
# a track - a tracks , sim:0.9093 - Deleting a tracks
# a trash can - trash cans , sim:0.9040 - Deleting trash cans
# a wall - walls , sim:0.9192 - Deleting walls
# armrests (optional) - armrests on either side , sim:0.9070 - Deleting armrests (optional)
# beady eyes - two small, beady eyes , sim:0.9012 - Deleting beady eyes
# black and white coloration - black and white coloring , sim:0.9336 - Deleting black and white coloring
# black and yellow stripes - yellow and black stripes , sim:0.9823 - Deleting yellow and black stripes
# black eyes - large, black eyes , sim:0.9206 - Deleting black eyes
# brown fur - brown or gray fur , sim:0.9093 - Deleting brown or gray fur
# brown fur - dark brown fur , sim:0.9407 - Deleting dark brown fur
# brown fur - long, brown fur , sim:0.9300 - Deleting brown fur
# brown, gray, or red fur - gray or brown fur , sim:0.9156 - Deleting brown, gray, or red fur
# building - buildings , sim:0.9238 - Deleting buildings
# claws - sharp claws , sim:0.9060 - Deleting claws
# dark green leaves - green leaves , sim:0.9291 - Deleting dark green leaves
# drooping branches - long, drooping branches , sim:0.9546 - Deleting drooping branches
# eight legs - eight long legs , sim:0.9319 - Deleting eight long legs
# eight legs - six legs , sim:0.9427 - Deleting six legs
# female - male , sim:0.9284 - Deleting female
# fins at the base - fins at the other end , sim:0.9174 - Deleting fins at the base
# flippers - flippers on the sides , sim:0.9128 - Deleting flippers
# four legs - four legs for support , sim:0.9130 - Deleting four legs for support
# four legs - four short legs , sim:0.9264 - Deleting four short legs
# garden equipment - lawn equipment , sim:0.9138 - Deleting lawn equipment
# gray or brown fur - grey or black fur , sim:0.9426 - Deleting grey or black fur
# has a boyish face - has a boyish haircut , sim:0.9013 - Deleting has a boyish haircut
# large ears - large, pointy ears , sim:0.9167 - Deleting large ears
# large wheels - large, powerful wheels , sim:0.9479 - Deleting large, powerful wheels
# large, black eyes - small black eyes , sim:0.9295 - Deleting small black eyes
# large, muscular hind legs - long, powerful hind legs , sim:0.9147 - Deleting large, muscular hind legs
# large, pointy ears - large, round ears , sim:0.9171 - Deleting large, round ears
# large, sharp teeth - sharp teeth , sim:0.9392 - Deleting sharp teeth
# large, sharp teeth - sharp teeth and claws , sim:0.9168 - Deleting sharp teeth and claws
# long, brown fur - reddish brown fur , sim:0.9003 - Deleting reddish brown fur
# long, powerful hind legs - powerful hind legs , sim:0.9675 - Deleting powerful hind legs
# made of metal or glass - made of steel and glass , sim:0.9397 - Deleting made of steel and glass
# mollusc - mollusk , sim:0.9096 - Deleting mollusk
# scales on the skin - scales or plates on the skin , sim:0.9480 - Deleting scales or plates on the skin
# sharp claws - sharply claws , sim:0.9367 - Deleting sharply claws
# shoes - sneakers , sim:0.9297 - Deleting sneakers
# short front legs - short legs , sim:0.9291 - Deleting short front legs
# short legs - short, stubby legs , sim:0.9324 - Deleting short, stubby legs
# small eyes - small eyes and ears , sim:0.9300 - Deleting small eyes
# smooth skin - smooth, glossy skin , sim:0.9130 - Deleting smooth, glossy skin
# smooth skin - smooth, shiny skin , sim:0.9357 - Deleting smooth, shiny skin
# tiny feet - tiny hands and feet , sim:0.9186 - Deleting tiny hands and feet
# two eyes on stalks - two small eyes on stalks , sim:0.9632 - Deleting two eyes on stalks
# two large claws - two large, pincer-like claws , sim:0.9251 - Deleting two large, pincer-like claws
# used to hold liquids or gas - used to hold liquids or gases , sim:0.9708 - Deleting used to hold liquids or gas
# wears clothes - wears revealing clothes , sim:0.9263 - Deleting wears revealing clothes
# webbed feet - webbed hind feet , sim:0.9318 - Deleting webbed hind feet
# 871

# %%
with open(save_name, "w") as f:
    f.write(concepts[0])
    for concept in concepts[1:]:
        f.write("\n" + concept)
